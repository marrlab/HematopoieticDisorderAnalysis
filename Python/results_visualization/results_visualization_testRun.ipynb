# %% [markdown]
# # Computational Profiling Reveals Age- and MDS-Related Changes in Hematopoietic Stem and Progenitor Cell Kinetics

# %% [markdown]
# ## Results Test Inference Procedure
# #### autor: Lisa Bast

# %%
from __future__ import division
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as col
import scipy.io as sio
import fnmatch as fnm
import matplotlib.patches as patches
import h5py
import math
#import webcolors
import os
import re
from matplotlib import rc
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

# %% [markdown]
# #### specify colors and cell type compartments

# %%
CT = ['HSC','MPP','MLP','CMP','GMP','MEP','mat']
cols_CT = ['#CC0000','#FF8000','#003366','#6600CC','#00994C','#57D7F7','#FFE00E','F7E464'];#'#A0A0A0'];

group_str = ['MDS','MDS_ASXL1','MDS_SF3B1','MDS_SF3B1_TET2','MDS_SF3B1_ASXL1','healthy']
cols_group = ['#FF0000','#FF3399', '#FD8002', '#AD07E3', '#A61919', '#194795'];

colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']

# %% [markdown]
# #### specify path were results can be found and figures should be saved

# %%
dir_str = os.getcwd()

# %%
dir_str
# Out:
# '/Users/lisa.bast/Documents/MATLAB_WD/class_1/HematopoiesisAnalysis/AnalysisAndModeling/BulkAnalysis/Healthy_MDS_Comparison/Parameter_Inference'

# %% [markdown]
# #### specify if figures should be saved

# %%
opt_save = True

# %% [markdown]
# #### load defined functions

# %%
os.chdir(dir_str)
# %run "definedFunctions.ipynb"

# %% [markdown]
# #### set general graphic settings

# %%
plt = loadPltSettings(50,10) #fonsize, markersize

# %% [markdown]
# #### specify results you are interested in:

# %%
N_is = 3;
M_names_sim = list('A')#list('ABCDEFGHIJ')
M_names_opt = list('A')
subfolder_str_Test = []
model_str = list()
for M_ID in M_names_opt:
    subfolder_str_Test.append("model_"+M_ID+"_model/")
    model_str.append("model_"+M_ID)

I_names = ['1','2','3']
I_names = ['1_weak_noise','1_middle_noise','1_strong_noise']
subsubfolder_str_Test = []
for I_ID in I_names:
    subsubfolder_str_Test.append("individual_"+I_ID)

# %% [markdown]
# ##### noise type:

# %%
noise_type = 'LogNormal'
#noise_type = 'LogLaplace'

# %% [markdown]
# ### 1) 3 noise levels at once, with constraints

# %%
noise_level_str = 'weak_middle_strong'
folder_str_Test = []
for M_ID in M_names_sim:
    folder_str_Test.append("/results_test_inference_procedure_7divs_"+str(N_is)+"iS_HO_"+noise_type+"_"+noise_level_str+"_fit_iC/")

# %%
plt.style.use('classic')
plt.rcParams['grid.alpha'] = 0
plt.rcParams['font.size'] = 30
plt.rcParams['axes.edgecolor'] ='black'
plt.rcParams['axes.facecolor'] ='white'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['figure.edgecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['figure.titlesize'] = 35
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['axes.labelsize']=30
plt.rcParams['lines.markersize']=20
plt.rcParams['legend.fontsize'] = 20

# %%
last_subsubfolder_str_Test=list()
last_subsubfolder_str_Test.append(subsubfolder_str_Test[len(subsubfolder_str_Test)-1])
par_T = 'log10'
rot_deg = 90
bool_test_par = True
alpha_errorband = 0.5
colors=['#000000']
opt_comparison ='testPars_vs_optPars'
opt_sample_ID = 'short'
plot_par_with_CI_vs_individuals(dir_str, folder_str_Test, subfolder_str_Test, subsubfolder_str_Test, last_subsubfolder_str_Test, [],[],M_names_sim, M_names_opt, CT, par_T,colors,opt_comparison, rot_deg,opt_sample_ID,False,bool_test_par,alpha_errorband,opt_save)

# %%
par_T = 'lin'
plot_par_with_CI_vs_individuals(dir_str, folder_str_Test, subfolder_str_Test, subsubfolder_str_Test, last_subsubfolder_str_Test, [],[],M_names_sim, M_names_opt, CT, par_T,colors,opt_comparison, rot_deg,opt_sample_ID,False,bool_test_par,alpha_errorband,opt_save)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a4c222a7a450> in <module>
#       1 par_T = 'lin'
# ----> 2 plot_par_with_CI_vs_individuals(dir_str, folder_str_Test, subfolder_str_Test, subsubfolder_str_Test, last_subsubfolder_str_Test, [],[],M_names_sim, M_names_opt, CT, par_T,colors,opt_comparison, rot_deg,opt_sample_ID,False,bool_test_par,alpha_errorband,opt_save)
#
# <ipython-input-23-4624359a20bc> in plot_par_with_CI_vs_individuals(main_folder_matlab, F_str, SF_str, SSF_str, last_SSF_str, samples_excluded_H, samples_excluded_MDS, M_names_sim, M_names_opt, states, par_transformation, colors, opt_comparison, rot_deg, opt_sample_ID, bool_fit_repetitions_seperately, bool_test_par, alpha_errorband, opt_save)
#     121                                     ar=DF_2[rate]
#     122                                     ci = [DF_2[rate+'_CI_l'], DF_2[rate+'_CI_u']]
# --> 123                                 CI_G,mean_G = confidence_interval_logNorm_distr_rates(ar, ci, 0.05, alpha_errorband)
#     124                                 axes[s_id,col].add_patch(patches.Rectangle((offset[g_id]-W, CI_G[0]), width=w_baseline-1+W*2, height=(CI_G[1]-CI_G[0]),color=colors[g_id],alpha=0.15,label=str(int(100-100*alpha_errorband))+'% confidence interval for group '+ group_str[g_id]))
#     125                                 axes[s_id,col].plot([offset[g_id]-W*2,offset[g_id]+w_baseline-1+W],[mean_G, mean_G],lw=2,ls='--',color=colors[g_id],label='mean rate '+group_str[g_id])
#
# <ipython-input-29-a1496ef835f4> in confidence_interval_logNorm_distr_rates(r, ci_pl, alpha_ci_pl, alpha)
#       1 def confidence_interval_logNorm_distr_rates(r, ci_pl, alpha_ci_pl, alpha):
# ----> 2     pdf_hat = random_numbers_logNorm_distr_rates(r, ci_pl, alpha_ci_pl, 1000)
#       3     CI = np.percentile(pdf_hat,[(alpha/2)*100,(1-alpha/2)*100])
#       4     mean = np.mean(pdf_hat)
#       5     return CI,mean
#
# <ipython-input-29-c57c9894e67e> in random_numbers_logNorm_distr_rates(r, ci_pl, alpha_ci_pl, n)
#       1 def random_numbers_logNorm_distr_rates(r, ci_pl, alpha_ci_pl, n):
# ----> 2     z_l = stats.norm.ppf(alpha_ci_pl/2)
#       3     z_u = stats.norm.ppf(1-alpha_ci_pl/2)
#       4     pdf_hat = []
#       5     for idx in range(0,len(r)):
#
# NameError: name 'stats' is not defined

# %% [markdown]
# #### Model fit

# %%
plt.style.use('classic')
plt.rcParams['grid.alpha'] = 0
plt.rcParams['font.size'] = 30
plt.rcParams['axes.edgecolor'] ='black'
plt.rcParams['axes.facecolor'] ='white'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['figure.edgecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['figure.titlesize'] = 30
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['axes.labelsize']=30
plt.rcParams['lines.markersize']=10
plt.rcParams['legend.fontsize'] = 30
plt.rcParams['xtick.labelsize'] = 30
plt.rcParams['ytick.labelsize'] = 30

# %%
plotModelFitToData(dir_str, folder_str_Test, subfolder_str_Test, subsubfolder_str_Test, CT, cols_CT, True,opt_save)
